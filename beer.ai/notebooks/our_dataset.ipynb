# %% [markdown]
# # Our Dataset
#
# Collecting beer recipes for machine learning

# %% [markdown]
# ## Outline
# * What we want to know about beer
# * What beer data is out there
# * What is beerXML
#   * Load and print a beerXML file
#   * Compare brewtoad and brewersfriend: presence/absense of tags
# * How much did we get
#   * Count recipes
# * How did we represent it
#   * Print a DataFrame
# * What does the beer recipe landscape look like
#   * \# recipes/styles
#   * what's cloned the most often?
#   * most common malt, hop, yeast names
#   * batch sizes
# * Sneak preview: beer measurables (IBU, ABV, SRM)

# %%
import pandas as pd
import glob
from lxml import etree
from pprint import pprint

# %%
recipes_folder = "../recipes/brewtoad_recipes/"
files = glob.glob(recipes_folder + "*snpa*")
files[0:50]
# Out:
# ['../recipes/brewtoad_recipes/snpa-clone-17.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-attempt-with-hops-on-hand-and-extra-15l-5gal-mash-vers.xml',
#  '../recipes/brewtoad_recipes/snpa-klon-nr-2-836cfe.xml',
#  '../recipes/brewtoad_recipes/snpa-15.xml',
#  '../recipes/brewtoad_recipes/snpa-14.xml',
#  '../recipes/brewtoad_recipes/mnir-snpa-clone-00499c.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-tweaked.xml',
#  '../recipes/brewtoad_recipes/snpa-161007.xml',
#  '../recipes/brewtoad_recipes/snpa-2-ccd326.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-16.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-28.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-14.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-90e7aa.xml',
#  '../recipes/brewtoad_recipes/snpa-ipa-1.xml',
#  '../recipes/brewtoad_recipes/snpabyanders.xml',
#  '../recipes/brewtoad_recipes/snpa2-9d878c.xml',
#  '../recipes/brewtoad_recipes/snpa-9.xml',
#  '../recipes/brewtoad_recipes/snpa-16.xml',
#  '../recipes/brewtoad_recipes/snpa-8.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-15.xml',
#  '../recipes/brewtoad_recipes/08-2010-21-snpa-3.xml',
#  '../recipes/brewtoad_recipes/snpa-attempt-2012-01-16-version-a-1.xml',
#  '../recipes/brewtoad_recipes/american-pale-snpa-clone.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-11.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-39.xml',
#  '../recipes/brewtoad_recipes/home-brew-snpa-clone.xml',
#  '../recipes/brewtoad_recipes/snpa-13.xml',
#  '../recipes/brewtoad_recipes/snpa-12.xml',
#  '../recipes/brewtoad_recipes/snpa-2-1.xml',
#  '../recipes/brewtoad_recipes/snpa-161203.xml',
#  '../recipes/brewtoad_recipes/snpa-grande.xml',
#  '../recipes/brewtoad_recipes/snpa.xml',
#  '../recipes/brewtoad_recipes/snpale.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-10.xml',
#  '../recipes/brewtoad_recipes/snpa-attempt-2012-01-16-version.xml',
#  '../recipes/brewtoad_recipes/15-snpa-clone.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-12.xml',
#  '../recipes/brewtoad_recipes/ahs-snpa.xml',
#  '../recipes/brewtoad_recipes/snpa-b7e029.xml',
#  '../recipes/brewtoad_recipes/snpa-10gal-mash-version.xml',
#  '../recipes/brewtoad_recipes/snpa-10.xml',
#  '../recipes/brewtoad_recipes/snpa-all-grain-bitter-clone.xml',
#  '../recipes/brewtoad_recipes/snpa-11.xml',
#  '../recipes/brewtoad_recipes/snpa-82e0f2.xml',
#  '../recipes/brewtoad_recipes/snpa-clone-13.xml',
#  '../recipes/brewtoad_recipes/snpa-extract-clone-us-05.xml',
#  '../recipes/brewtoad_recipes/snpaclone.xml',
#  '../recipes/brewtoad_recipes/snpa-2016-fb3947.xml',
#  '../recipes/brewtoad_recipes/ag-snpa-clone-125litre-1.xml',
#  '../recipes/brewtoad_recipes/mini-batch-islander-snpa.xml']

# %%
len(files)
# Out:
# 166

# %%
bt_snpa_example = "../recipes/brewtoad_recipes/snpaclone.xml"

# %%
with open(bt_snpa_example, "r") as f:
    beerxml = f.read()

# %%
pprint(beerxml)
# Out:
# ('<?xml version="1.0" encoding="UTF-8"?>\n'
#  '<RECIPES>\n'
#  '  <RECIPE>\n'
#  '    <NAME>SNPAclone</NAME>\n'
#  '    <STYLE>\n'
#  '      <STYLE_GUIDE>BJCP</STYLE_GUIDE>\n'
#  '      <VERSION>1</VERSION>\n'
#  '      <NAME>American Pale Ale</NAME>\n'
#  '      <STYLE_LETTER>A</STYLE_LETTER>\n'
#  '      <CATEGORY_NUMBER>10</CATEGORY_NUMBER>\n'
#  '      <TYPE>Ale</TYPE>\n'
#  '      <OG_MIN>1.045</OG_MIN>\n'
#  '      <OG_MAX>1.06</OG_MAX>\n'
#  '      <FG_MIN>1.01</FG_MIN>\n'
#  '      <FG_MAX>1.015</FG_MAX>\n'
#  '      <IBU_MIN>30.0</IBU_MIN>\n'
#  '      <IBU_MAX>45.0</IBU_MAX>\n'
#  '      <COLOR_MIN>5.0</COLOR_MIN>\n'
#  '      <COLOR_MAX>14.0</COLOR_MAX>\n'
#  '      <ABV_MIN>4.5</ABV_MIN>\n'
#  '      <ABV_MAX>6.2</ABV_MAX>\n'
#  '    </STYLE>\n'
#  '    <FERMENTABLES>\n'
#  '      <FERMENTABLE>\n'
#  '        <NAME>2-Row (US)</NAME>\n'
#  '        <ORIGIN></ORIGIN>\n'
#  '        <TYPE>Base Malt</TYPE>\n'
#  '        <YIELD>79.89635068019865</YIELD>\n'
#  '        <AMOUNT>4.535923700000001</AMOUNT>\n'
#  '        <DISPLAY_AMOUNT>10.0 lb</DISPLAY_AMOUNT>\n'
#  '        <POTENTIAL>1.037</POTENTIAL>\n'
#  '        <COLOR>1</COLOR>\n'
#  '        <DISPLAY_COLOR>1 SRM</DISPLAY_COLOR>\n'
#  '        <ADD_AFTER_BOIL></ADD_AFTER_BOIL>\n'
#  '        <COARSE_FINE_DIFF></COARSE_FINE_DIFF>\n'
#  '        <MOISTURE></MOISTURE>\n'
#  '        <DIASTATIC_POWER></DIASTATIC_POWER>\n'
#  '        <PROTEIN></PROTEIN>\n'
#  '        <MAX_IN_BATCH></MAX_IN_BATCH>\n'
#  '        <RECOMMEND_MASH></RECOMMEND_MASH>\n'
#  '        <IBU_GAL_PER_LB></IBU_GAL_PER_LB>\n'
#  '        <NOTES></NOTES>\n'
#  '      </FERMENTABLE>\n'
#  '      <FERMENTABLE>\n'
#  '        <NAME>Crystal 40L (CA)</NAME>\n'
#  '        <ORIGIN></ORIGIN>\n'
#  '        <TYPE>Caramel/Crystal Malt</TYPE>\n'
#  '        <YIELD>73.41826819261497</YIELD>\n'
#  '        <AMOUNT>0.45359237</AMOUNT>\n'
#  '        <DISPLAY_AMOUNT>1.0 lb</DISPLAY_AMOUNT>\n'
#  '        <POTENTIAL>1.034</POTENTIAL>\n'
#  '        <COLOR>40</COLOR>\n'
#  '        <DISPLAY_COLOR>40 SRM</DISPLAY_COLOR>\n'
#  '        <ADD_AFTER_BOIL></ADD_AFTER_BOIL>\n'
#  '        <COARSE_FINE_DIFF></COARSE_FINE_DIFF>\n'
#  '        <MOISTURE></MOISTURE>\n'
#  '        <DIASTATIC_POWER></DIASTATIC_POWER>\n'
#  '        <PROTEIN></PROTEIN>\n'
#  '        <MAX_IN_BATCH></MAX_IN_BATCH>\n'
#  '        <RECOMMEND_MASH></RECOMMEND_MASH>\n'
#  '        <IBU_GAL_PER_LB></IBU_GAL_PER_LB>\n'
#  '        <NOTES></NOTES>\n'
#  '      </FERMENTABLE>\n'
#  '    </FERMENTABLES>\n'
#  '    <HOPS>\n'
#  '      <HOP>\n'
#  '        <NAME>Perle (US)</NAME>\n'
#  '        <ORIGIN>United States</ORIGIN>\n'
#  '        <ALPHA>7.75</ALPHA>\n'
#  '        <BETA></BETA>\n'
#  '        <AMOUNT>0.0283495</AMOUNT>\n'
#  '        <DISPLAY_AMOUNT>1.0 oz</DISPLAY_AMOUNT>\n'
#  '        <USE>Boil</USE>\n'
#  '        <FORM>Pellet</FORM>\n'
#  '        <TIME>60</TIME>\n'
#  '        <DISPLAY_TIME>60.0 min</DISPLAY_TIME>\n'
#  '        <NOTES></NOTES>\n'
#  '      </HOP>\n'
#  '      <HOP>\n'
#  '        <NAME>Cascade (US)</NAME>\n'
#  '        <ORIGIN>United States</ORIGIN>\n'
#  '        <ALPHA>7.0</ALPHA>\n'
#  '        <BETA></BETA>\n'
#  '        <AMOUNT>0.0283495</AMOUNT>\n'
#  '        <DISPLAY_AMOUNT>1.0 oz</DISPLAY_AMOUNT>\n'
#  '        <USE>Boil</USE>\n'
#  '        <FORM>Pellet</FORM>\n'
#  '        <TIME>15</TIME>\n'
#  '        <DISPLAY_TIME>15.0 min</DISPLAY_TIME>\n'
#  '        <NOTES>Very successful and well-established American aroma hop '
#  "developed by Oregon State University's breeding program in 1956 from Fuggle "
#  'and Serebrianker (a Russian variety), but not released for cultivation until '
#  '1972. Gives the distinct citrus/grapefruit aroma to the Pale Ale produced by '
#  "California's Sierra Nevada Brewing Company, the best-selling American pale "
#  'ale in the country. One of the "Three Cs" along with Centennial and '
#  'Columbus. Named for the Cascade Range. Substitutes: Centennial and Columbus '
#  '(but they have a higher Alpha Acid content).</NOTES>\n'
#  '      </HOP>\n'
#  '      <HOP>\n'
#  '        <NAME>Cascade (US)</NAME>\n'
#  '        <ORIGIN>United States</ORIGIN>\n'
#  '        <ALPHA>7.0</ALPHA>\n'
#  '        <BETA></BETA>\n'
#  '        <AMOUNT>0.0283495</AMOUNT>\n'
#  '        <DISPLAY_AMOUNT>1.0 oz</DISPLAY_AMOUNT>\n'
#  '        <USE>Boil</USE>\n'
#  '        <FORM>Pellet</FORM>\n'
#  '        <TIME>0</TIME>\n'
#  '        <DISPLAY_TIME>0.0 min</DISPLAY_TIME>\n'
#  '        <NOTES>Very successful and well-established American aroma hop '
#  "developed by Oregon State University's breeding program in 1956 from Fuggle "
#  'and Serebrianker (a Russian variety), but not released for cultivation until '
#  '1972. Gives the distinct citrus/grapefruit aroma to the Pale Ale produced by '
#  "California's Sierra Nevada Brewing Company, the best-selling American pale "
#  'ale in the country. One of the "Three Cs" along with Centennial and '
#  'Columbus. Named for the Cascade Range. Substitutes: Centennial and Columbus '
#  '(but they have a higher Alpha Acid content).</NOTES>\n'
#  '      </HOP>\n'
#  '      <HOP>\n'
#  '        <NAME>Cascade (US)</NAME>\n'
#  '        <ORIGIN>United States</ORIGIN>\n'
#  '        <ALPHA>7.0</ALPHA>\n'
#  '        <BETA></BETA>\n'
#  '        <AMOUNT>0.0283495</AMOUNT>\n'
#  '        <DISPLAY_AMOUNT>1.0 oz</DISPLAY_AMOUNT>\n'
#  '        <USE>Dry Hop</USE>\n'
#  '        <FORM>Pellet</FORM>\n'
#  '        <TIME>7200</TIME>\n'
#  '        <DISPLAY_TIME>5 days</DISPLAY_TIME>\n'
#  '        <NOTES>Very successful and well-established American aroma hop '
#  "developed by Oregon State University's breeding program in 1956 from Fuggle "
#  'and Serebrianker (a Russian variety), but not released for cultivation until '
#  '1972. Gives the distinct citrus/grapefruit aroma to the Pale Ale produced by '
#  "California's Sierra Nevada Brewing Company, the best-selling American pale "
#  'ale in the country. One of the "Three Cs" along with Centennial and '
#  'Columbus. Named for the Cascade Range. Substitutes: Centennial and Columbus '
#  '(but they have a higher Alpha Acid content).</NOTES>\n'
#  '      </HOP>\n'
#  '    </HOPS>\n'
#  '    <YEASTS>\n'
#  '      <YEAST>\n'
#  '        <LABORATORY>Fermentis</LABORATORY>\n'
#  '        <NAME>Safale US-05</NAME>\n'
#  '        <TYPE>Ale</TYPE>\n'
#  '        <FORM>Dry</FORM>\n'
#  '        <ATTENUATION>85.5</ATTENUATION>\n'
#  '      </YEAST>\n'
#  '    </YEASTS>\n'
#  '    <MISCS/>\n'
#  '    <TYPE>All Grain</TYPE>\n'
#  '    <BREWER>wmschm</BREWER>\n'
#  '    <BATCH_SIZE>20.81976479</BATCH_SIZE>\n'
#  '    <BOIL_SIZE>26.49788246</BOIL_SIZE>\n'
#  '    <BOIL_TIME>60</BOIL_TIME>\n'
#  '    <EFFICIENCY>75.0</EFFICIENCY>\n'
#  '  </RECIPE>\n'
#  '</RECIPES>\n')

# %%
xml = etree.parse(bt_snpa_example)
for e in xml.iter():
    print(xml.getpath(e))
# Out:
# /RECIPES
# /RECIPES/RECIPE
# /RECIPES/RECIPE/NAME
# /RECIPES/RECIPE/STYLE
# /RECIPES/RECIPE/STYLE/STYLE_GUIDE
# /RECIPES/RECIPE/STYLE/VERSION
# /RECIPES/RECIPE/STYLE/NAME
# /RECIPES/RECIPE/STYLE/STYLE_LETTER
# /RECIPES/RECIPE/STYLE/CATEGORY_NUMBER
# /RECIPES/RECIPE/STYLE/TYPE
# /RECIPES/RECIPE/STYLE/OG_MIN
# /RECIPES/RECIPE/STYLE/OG_MAX
# /RECIPES/RECIPE/STYLE/FG_MIN
# /RECIPES/RECIPE/STYLE/FG_MAX
# /RECIPES/RECIPE/STYLE/IBU_MIN
# /RECIPES/RECIPE/STYLE/IBU_MAX
# /RECIPES/RECIPE/STYLE/COLOR_MIN
# /RECIPES/RECIPE/STYLE/COLOR_MAX
# /RECIPES/RECIPE/STYLE/ABV_MIN
# /RECIPES/RECIPE/STYLE/ABV_MAX
# /RECIPES/RECIPE/FERMENTABLES
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/NAME
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/ORIGIN
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/TYPE
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/YIELD
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/AMOUNT
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/DISPLAY_AMOUNT
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/POTENTIAL
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/COLOR
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/DISPLAY_COLOR
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/ADD_AFTER_BOIL
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/COARSE_FINE_DIFF
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/MOISTURE
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/DIASTATIC_POWER
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/PROTEIN
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/MAX_IN_BATCH
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/RECOMMEND_MASH
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/IBU_GAL_PER_LB
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/NOTES
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/NAME
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/ORIGIN
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/TYPE
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/YIELD
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/AMOUNT
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/DISPLAY_AMOUNT
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/POTENTIAL
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/COLOR
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/DISPLAY_COLOR
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/ADD_AFTER_BOIL
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/COARSE_FINE_DIFF
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/MOISTURE
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/DIASTATIC_POWER
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/PROTEIN
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/MAX_IN_BATCH
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/RECOMMEND_MASH
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/IBU_GAL_PER_LB
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/NOTES
# /RECIPES/RECIPE/HOPS
# /RECIPES/RECIPE/HOPS/HOP[1]
# /RECIPES/RECIPE/HOPS/HOP[1]/NAME
# /RECIPES/RECIPE/HOPS/HOP[1]/ORIGIN
# /RECIPES/RECIPE/HOPS/HOP[1]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[1]/BETA
# /RECIPES/RECIPE/HOPS/HOP[1]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[1]/DISPLAY_AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[1]/USE
# /RECIPES/RECIPE/HOPS/HOP[1]/FORM
# /RECIPES/RECIPE/HOPS/HOP[1]/TIME
# /RECIPES/RECIPE/HOPS/HOP[1]/DISPLAY_TIME
# /RECIPES/RECIPE/HOPS/HOP[1]/NOTES
# /RECIPES/RECIPE/HOPS/HOP[2]
# /RECIPES/RECIPE/HOPS/HOP[2]/NAME
# /RECIPES/RECIPE/HOPS/HOP[2]/ORIGIN
# /RECIPES/RECIPE/HOPS/HOP[2]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[2]/BETA
# /RECIPES/RECIPE/HOPS/HOP[2]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[2]/DISPLAY_AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[2]/USE
# /RECIPES/RECIPE/HOPS/HOP[2]/FORM
# /RECIPES/RECIPE/HOPS/HOP[2]/TIME
# /RECIPES/RECIPE/HOPS/HOP[2]/DISPLAY_TIME
# /RECIPES/RECIPE/HOPS/HOP[2]/NOTES
# /RECIPES/RECIPE/HOPS/HOP[3]
# /RECIPES/RECIPE/HOPS/HOP[3]/NAME
# /RECIPES/RECIPE/HOPS/HOP[3]/ORIGIN
# /RECIPES/RECIPE/HOPS/HOP[3]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[3]/BETA
# /RECIPES/RECIPE/HOPS/HOP[3]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[3]/DISPLAY_AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[3]/USE
# /RECIPES/RECIPE/HOPS/HOP[3]/FORM
# /RECIPES/RECIPE/HOPS/HOP[3]/TIME
# /RECIPES/RECIPE/HOPS/HOP[3]/DISPLAY_TIME
# /RECIPES/RECIPE/HOPS/HOP[3]/NOTES
# /RECIPES/RECIPE/HOPS/HOP[4]
# /RECIPES/RECIPE/HOPS/HOP[4]/NAME
# /RECIPES/RECIPE/HOPS/HOP[4]/ORIGIN
# /RECIPES/RECIPE/HOPS/HOP[4]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[4]/BETA
# /RECIPES/RECIPE/HOPS/HOP[4]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[4]/DISPLAY_AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[4]/USE
# /RECIPES/RECIPE/HOPS/HOP[4]/FORM
# /RECIPES/RECIPE/HOPS/HOP[4]/TIME
# /RECIPES/RECIPE/HOPS/HOP[4]/DISPLAY_TIME
# /RECIPES/RECIPE/HOPS/HOP[4]/NOTES
# /RECIPES/RECIPE/YEASTS
# /RECIPES/RECIPE/YEASTS/YEAST
# /RECIPES/RECIPE/YEASTS/YEAST/LABORATORY
# /RECIPES/RECIPE/YEASTS/YEAST/NAME
# /RECIPES/RECIPE/YEASTS/YEAST/TYPE
# /RECIPES/RECIPE/YEASTS/YEAST/FORM
# /RECIPES/RECIPE/YEASTS/YEAST/ATTENUATION
# /RECIPES/RECIPE/MISCS
# /RECIPES/RECIPE/TYPE
# /RECIPES/RECIPE/BREWER
# /RECIPES/RECIPE/BATCH_SIZE
# /RECIPES/RECIPE/BOIL_SIZE
# /RECIPES/RECIPE/BOIL_TIME
# /RECIPES/RECIPE/EFFICIENCY

# %% [markdown]
# Original Ken Grossman recipe: https://sierranevada.com/blog/pale-ale-homebrew-recipe/

# %%
recipes_folder = "../recipes/recipes_brewersfriend/"
files = glob.glob(recipes_folder + "*")

# %%
with pd.HDFStore("../all_recipes.h5") as store:
    core = store.select(key="/core")

# %%
clones = core[core.name.str.contains("clone")].name

# %%
clone_words = pd.Series([item for sublist in list(clones.str.split()) for item in sublist])

# %%
clone_words.value_counts().head(40)
# Out:
# clone       13586
# ale          1381
# ipa          1200
# -             789
# clone)        558
# stout         544
# pale          503
# the           410
# sierra        379
# nevada        361
# stone         346
# porter        327
# pliny         326
# red           297
# hearted       282
# version)      273
# two           243
# dust          232
# elder         230
# zombie        224
# brown         213
# black         206
# 2             206
# old           201
# fat           196
# blue          190
# tire          188
# extract       186
# moon          182
# (clone)       180
# bastard       178
# head          174
# amber         169
# bell's        157
# white         156
# hop           156
# milk          150
# of            146
# 1             145
# double        142
# dtype: int64

# %%
bf_snpa = core[(core.origin == "brewersfriend") & (core.name.str.contains("snpa"))]

# %%
bf_snpa
# Out:
#         batch_size  boil_size  boil_time                         brewer  \
# id
# 333780    5.800000   8.500000       60.0                            NaN
# 344204   41.639530  47.620480       60.0                            NaN
# 346531   22.712471  28.390588       60.0  my adv / ozarks mountain brew
# 349787   18.927059  28.390588       60.0                            aih
# 351027   20.000000  12.000000       60.0                            NaN
# 354349   20.819765  28.390588       60.0                            NaN
# 358117   18.000000  25.000000       60.0                            NaN
# 381521   22.000000  26.500000       90.0                            NaN
# 385308   11.356235  13.248941       40.0                            NaN
# 388437   41.639530  51.103059       60.0                            NaN
# 389063   42.000000  53.000000       90.0                      byo staff
# 392061   20.819765  28.390588       60.0                            aih
# 392062   43.532235  51.103059       60.0                            NaN
# 392206   39.747202  47.578084       60.0                            NaN
# 394758   20.819765  24.983718       60.0  my adv / ozarks mountain brew
# 400612   19.873412  17.034353       60.0      myself with google's help
# 402457   18.927059  24.605177       60.0                  matthew smith
#
#         efficiency                        name         origin  \
# id
# 333780        0.80                        snpa  brewersfriend
# 344204        0.80                 snpa 10 gal  brewersfriend
# 346531        0.76                  snpa clone  brewersfriend
# 349787        0.70                        snpa  brewersfriend
# 351027        0.70              snpa clone keg  brewersfriend
# 354349        0.75                  snpa clone  brewersfriend
# 358117        0.64                        snpa  brewersfriend
# 381521        0.75       toms snpa clone (fwh)  brewersfriend
# 385308        0.80              snpa clone-ish  brewersfriend
# 388437        0.80                        snpa  brewersfriend
# 389063        0.72                        snpa  brewersfriend
# 392061        0.75                        snpa  brewersfriend
# 392062        0.76           snpa clone 10 gal  brewersfriend
# 392206        0.85  nierra sevada (snpa clone)  brewersfriend
# 394758        0.70                  snpa clone  brewersfriend
# 400612        0.70                  snpa clone  brewersfriend
# 402457        0.70                  snpa clone  brewersfriend
#
#                              recipe_file  src_abv  src_color  src_fg  src_ibu  \
# id
# 333780  recipes/brewersfriend/266866.xml     5.47       9.42   1.011    42.39
# 344204  recipes/brewersfriend/303792.xml     5.65       9.05   1.010    43.06
# 346531  recipes/brewersfriend/232281.xml     5.36       7.49   1.009    37.92
# 349787  recipes/brewersfriend/417766.xml     5.72       8.02   1.012    63.78
# 351027  recipes/brewersfriend/335632.xml     5.57      13.20   1.008    28.17
# 354349  recipes/brewersfriend/125052.xml     5.89       7.62   1.015    55.23
# 358117  recipes/brewersfriend/545021.xml     5.40       9.46   1.013    44.24
# 381521  recipes/brewersfriend/449635.xml     5.30       8.01   1.012    55.88
# 385308    recipes/brewersfriend/1012.xml     5.31       6.13   1.013    58.47
# 388437  recipes/brewersfriend/354940.xml     5.25       8.22   1.013    40.46
# 389063  recipes/brewersfriend/399311.xml     5.25       9.10   1.012    48.83
# 392061  recipes/brewersfriend/525124.xml     5.83       7.46   1.010    67.44
# 392062  recipes/brewersfriend/372368.xml     5.28       6.48   1.013    43.54
# 392206  recipes/brewersfriend/189765.xml     4.90       6.60   1.012    28.50
# 394758  recipes/brewersfriend/232273.xml     5.38       7.95   1.009    40.68
# 400612  recipes/brewersfriend/569856.xml     6.14       9.43   1.009    40.70
# 402457   recipes/brewersfriend/29977.xml     4.82      10.62   1.014    37.40
#
#         src_og style_category style_guide         style_name  style_version
# id
# 333780   1.053            10a        bjcp  american pale ale            1.0
# 344204   1.053            10a        bjcp  american pale ale            1.0
# 346531   1.050            10a        bjcp  american pale ale            1.0
# 349787   1.056            10a        bjcp  american pale ale            1.0
# 351027   1.051            18b        bjcp  american pale ale            1.0
# 354349   1.060            10a        bjcp  american pale ale            1.0
# 358117   1.054            18b        bjcp  american pale ale            1.0
# 381521   1.053            10a        bjcp  american pale ale            1.0
# 385308   1.053            10a        bjcp  american pale ale            1.0
# 388437   1.053            18b        bjcp  american pale ale            1.0
# 389063   1.052            18b        bjcp  american pale ale            1.0
# 392061   1.055            18b        bjcp  american pale ale            1.0
# 392062   1.054            18b        bjcp  american pale ale            1.0
# 392206   1.050            10a        bjcp  american pale ale            1.0
# 394758   1.050            10a        bjcp  american pale ale            1.0
# 400612   1.056            18b        bjcp  american pale ale            1.0
# 402457   1.051            10a        bjcp  american pale ale            1.0

# %%
core.origin.value_counts()
# Out:
# brewtoad         330790
# brewersfriend     72367
# Name: origin, dtype: int64

# %%
bf_snpa_example = "../recipes/recipes_brewersfriend/232281.xml"

# %%
with open(bf_snpa_example, "r") as f:
    bf_snpa_beerxml = f.read()

# %%
pprint(bf_snpa_beerxml)
# Out:
# ('<?xml version="1.0" encoding="UTF-8"?>\n'
#  '<RECIPES>\n'
#  ' <RECIPE>\n'
#  '  <NAME>SNPA Clone</NAME>\n'
#  '  <VERSION>1</VERSION>\n'
#  '  <TYPE>All Grain</TYPE>\n'
#  '  <BREWER>MY ADV / Ozarks Mountain Brew</BREWER>\n'
#  '  <DISPLAY_BATCH_SIZE>6 gal</DISPLAY_BATCH_SIZE>\n'
#  '  <DISPLAY_BOIL_SIZE>7.5 gal</DISPLAY_BOIL_SIZE>\n'
#  '  <BATCH_SIZE>22.71247068</BATCH_SIZE>\n'
#  '  <BOIL_SIZE>28.39058835</BOIL_SIZE>\n'
#  '  <BOIL_TIME>60</BOIL_TIME>\n'
#  '  <EFFICIENCY>76</EFFICIENCY>\n'
#  '  <NOTES>Water Needed. 8.71 gallons in to kettle. Single infusion no '
#  'sparge.  Filled to 8.75 set boil to med to hard and had 6 gallons into '
#  'fermenter with no loss.&#13;\n'
#  '&#13;\n'
#  'No squeeze bag: Hang and drip. Place drippings back into kettle before boil. '
#  '&#13;\n'
#  '&#13;\n'
#  'Ambient Temp = 68F&#13;\n'
#  'Estimated Strike Temp: 158.47F&#13;\n'
#  'Real Strike Temp Should be: 155F&#13;\n'
#  '60 min rest at 153F&#13;\n'
#  '&#13;\n'
#  'Hop Addition: 0 Min = Flame out&#13;\n'
#  'Dry Hop: After primary fermentations(4 Days)&#13;\n'
#  '&#13;\n'
#  'Yeast, No Starter, OG was 1.050 so used two packages of US-05 and Rehydrated '
#  "using Ferments' directions.</NOTES>\n"
#  '  <PRIMARY_TEMP>18.888888888889</PRIMARY_TEMP>\n'
#  '  <EST_COLOR>7.49</EST_COLOR>\n'
#  '  <IBU>37.92</IBU>\n'
#  '  <IBU_METHOD>Tinseth</IBU_METHOD>\n'
#  '  <EST_ABV>5.36</EST_ABV>\n'
#  '  <EST_OG>1.05 sg</EST_OG>\n'
#  '  <EST_FG>1.009 sg</EST_FG>\n'
#  '  <OG>1.05</OG>\n'
#  '  <FG>1.009</FG>\n'
#  '  <PRIMING_SUGAR_NAME></PRIMING_SUGAR_NAME>\n'
#  '  <CARBONATION_USED></CARBONATION_USED>\n'
#  '  <BF_PRIMING_METHOD></BF_PRIMING_METHOD>\n'
#  '  <BF_PRIMING_AMOUNT></BF_PRIMING_AMOUNT>\n'
#  '  <BF_CO2_LEVEL></BF_CO2_LEVEL>\n'
#  '  <BF_CO2_UNIT>Volumes</BF_CO2_UNIT>\n'
#  '  <URL></URL>\n'
#  '  <BATCH_SIZE_MODE>f</BATCH_SIZE_MODE>\n'
#  '  <YEAST_STARTER>false</YEAST_STARTER>\n'
#  '  <NO_CHILL_EXTRA_MINUTES></NO_CHILL_EXTRA_MINUTES>\n'
#  '  <PITCH_RATE>1.0</PITCH_RATE>\n'
#  '  <FERMENTABLES>\n'
#  '   <FERMENTABLE>\n'
#  '    <NAME>Pale 2-Row</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <TYPE>Grain</TYPE>\n'
#  '    <AMOUNT>4.5359237</AMOUNT>\n'
#  '    <YIELD>80.43</YIELD>\n'
#  '    <COLOR>1.8</COLOR>\n'
#  '    <ADD_AFTER_BOIL>false</ADD_AFTER_BOIL>\n'
#  '    <ORIGIN>American</ORIGIN>\n'
#  '   </FERMENTABLE>\n'
#  '   <FERMENTABLE>\n'
#  '    <NAME>Caramel / Crystal 60L</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <TYPE>Grain</TYPE>\n'
#  '    <AMOUNT>0.3401942775</AMOUNT>\n'
#  '    <YIELD>73.91</YIELD>\n'
#  '    <COLOR>60</COLOR>\n'
#  '    <ADD_AFTER_BOIL>false</ADD_AFTER_BOIL>\n'
#  '    <ORIGIN>American</ORIGIN>\n'
#  '   </FERMENTABLE>\n'
#  '  </FERMENTABLES>\n'
#  '  <HOPS>\n'
#  '   <HOP>\n'
#  '    <NAME>Magnum</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <ALPHA>15</ALPHA>\n'
#  '    <AMOUNT>0.01417476155</AMOUNT>\n'
#  '    <USE>Boil</USE>\n'
#  '    <USER_HOP_USE>Boil</USER_HOP_USE>\n'
#  '    <TIME>60</TIME>\n'
#  '    <FORM>Leaf</FORM>\n'
#  '   </HOP>\n'
#  '   <HOP>\n'
#  '    <NAME>Perle</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <ALPHA>8.2</ALPHA>\n'
#  '    <AMOUNT>0.01417476155</AMOUNT>\n'
#  '    <USE>Boil</USE>\n'
#  '    <USER_HOP_USE>Boil</USER_HOP_USE>\n'
#  '    <TIME>30</TIME>\n'
#  '    <FORM>Leaf</FORM>\n'
#  '   </HOP>\n'
#  '   <HOP>\n'
#  '    <NAME>Cascade</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <ALPHA>7</ALPHA>\n'
#  '    <AMOUNT>0.0283495231</AMOUNT>\n'
#  '    <USE>Boil</USE>\n'
#  '    <USER_HOP_USE>Boil</USER_HOP_USE>\n'
#  '    <TIME>5</TIME>\n'
#  '    <FORM>Leaf</FORM>\n'
#  '   </HOP>\n'
#  '   <HOP>\n'
#  '    <NAME>Cascade</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <ALPHA>7</ALPHA>\n'
#  '    <AMOUNT>0.0283495231</AMOUNT>\n'
#  '    <USE>Boil</USE>\n'
#  '    <USER_HOP_USE>Boil</USER_HOP_USE>\n'
#  '    <TIME>0</TIME>\n'
#  '    <FORM>Leaf</FORM>\n'
#  '   </HOP>\n'
#  '   <HOP>\n'
#  '    <NAME>Cascade</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <ALPHA>7</ALPHA>\n'
#  '    <AMOUNT>0.0566990462</AMOUNT>\n'
#  '    <USE>Dry Hop</USE>\n'
#  '    <USER_HOP_USE>Dry Hop</USER_HOP_USE>\n'
#  '    <TIME>5760</TIME>\n'
#  '    <FORM>Leaf</FORM>\n'
#  '   </HOP>\n'
#  '  </HOPS>\n'
#  '  <MISCS>\n'
#  '   <MISC>\n'
#  '    <NAME>Whilrfoc Tablet</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <TYPE>Fining</TYPE>\n'
#  '    <USE>Boil</USE>\n'
#  '    <TIME>10</TIME>\n'
#  '    <AMOUNT>1</AMOUNT>\n'
#  '    <AMOUNT_IS_WEIGHT>true</AMOUNT_IS_WEIGHT>\n'
#  '   </MISC>\n'
#  '  </MISCS>\n'
#  '  <MASH>\n'
#  '   <NAME>Mash Steps</NAME>\n'
#  '   <VERSION>1</VERSION>\n'
#  '   <GRAIN_TEMP>20</GRAIN_TEMP>\n'
#  '   <MASH_STEPS>\n'
#  '    <MASH_STEP>\n'
#  '     <NAME>No Mash Out</NAME>\n'
#  '     <VERSION>1</VERSION>\n'
#  '     <TYPE>Infusion</TYPE>\n'
#  '     <STEP_TIME>60</STEP_TIME>\n'
#  '     <INFUSE_AMOUNT>33.122353075</INFUSE_AMOUNT>\n'
#  '     <STEP_TEMP>67.222222222222</STEP_TEMP>\n'
#  '    </MASH_STEP>\n'
#  '   </MASH_STEPS>\n'
#  '  </MASH>\n'
#  '  <YEASTS>\n'
#  '   <YEAST>\n'
#  '    <NAME>Safale - American Ale Yeast US-05</NAME>\n'
#  '    <VERSION>1</VERSION>\n'
#  '    <TYPE>Ale</TYPE>\n'
#  '    <FORM>Dry</FORM>\n'
#  '    <AMOUNT>0.11</AMOUNT>\n'
#  '    <AMOUNT_IS_WEIGHT>true</AMOUNT_IS_WEIGHT>\n'
#  '    <PRODUCT_ID>US-05</PRODUCT_ID>\n'
#  '    <LABORATORY>Fermentis / Safale</LABORATORY>\n'
#  '    <ATTENUATION>81</ATTENUATION>\n'
#  '    <FLOCCULATION>Medium</FLOCCULATION>\n'
#  '    <MIN_TEMPERATURE>12.222222222222</MIN_TEMPERATURE>\n'
#  '    <MAX_TEMPERATURE>25</MAX_TEMPERATURE>\n'
#  '   </YEAST>\n'
#  '  </YEASTS>\n'
#  '  <WATERS/>\n'
#  '  <STYLE>\n'
#  '   <NAME>American Pale Ale</NAME>\n'
#  '   <VERSION>1</VERSION>\n'
#  '   <CATEGORY>American Ale</CATEGORY>\n'
#  '   <CATEGORY_NUMBER>10</CATEGORY_NUMBER>\n'
#  '   <STYLE_LETTER>A</STYLE_LETTER>\n'
#  '   <STYLE_GUIDE>BJCP</STYLE_GUIDE>\n'
#  '   <TYPE>Ale</TYPE>\n'
#  '   <OG_MIN>1.045</OG_MIN>\n'
#  '   <OG_MAX>1.06</OG_MAX>\n'
#  '   <FG_MIN>1.01</FG_MIN>\n'
#  '   <FG_MAX>1.015</FG_MAX>\n'
#  '   <ABV_MIN>4.5</ABV_MIN>\n'
#  '   <ABV_MAX>6.2</ABV_MAX>\n'
#  '   <IBU_MIN>30</IBU_MIN>\n'
#  '   <IBU_MAX>45</IBU_MAX>\n'
#  '   <COLOR_MIN>5</COLOR_MIN>\n'
#  '   <COLOR_MAX>14</COLOR_MAX>\n'
#  '  </STYLE>\n'
#  ' </RECIPE>\n'
#  '</RECIPES>\n')

# %%
xml = etree.parse(bf_snpa_example)
for e in xml.iter():
    print(xml.getpath(e))
# Out:
# /RECIPES
# /RECIPES/RECIPE
# /RECIPES/RECIPE/NAME
# /RECIPES/RECIPE/VERSION
# /RECIPES/RECIPE/TYPE
# /RECIPES/RECIPE/BREWER
# /RECIPES/RECIPE/DISPLAY_BATCH_SIZE
# /RECIPES/RECIPE/DISPLAY_BOIL_SIZE
# /RECIPES/RECIPE/BATCH_SIZE
# /RECIPES/RECIPE/BOIL_SIZE
# /RECIPES/RECIPE/BOIL_TIME
# /RECIPES/RECIPE/EFFICIENCY
# /RECIPES/RECIPE/NOTES
# /RECIPES/RECIPE/PRIMARY_TEMP
# /RECIPES/RECIPE/EST_COLOR
# /RECIPES/RECIPE/IBU
# /RECIPES/RECIPE/IBU_METHOD
# /RECIPES/RECIPE/EST_ABV
# /RECIPES/RECIPE/EST_OG
# /RECIPES/RECIPE/EST_FG
# /RECIPES/RECIPE/OG
# /RECIPES/RECIPE/FG
# /RECIPES/RECIPE/PRIMING_SUGAR_NAME
# /RECIPES/RECIPE/CARBONATION_USED
# /RECIPES/RECIPE/BF_PRIMING_METHOD
# /RECIPES/RECIPE/BF_PRIMING_AMOUNT
# /RECIPES/RECIPE/BF_CO2_LEVEL
# /RECIPES/RECIPE/BF_CO2_UNIT
# /RECIPES/RECIPE/URL
# /RECIPES/RECIPE/BATCH_SIZE_MODE
# /RECIPES/RECIPE/YEAST_STARTER
# /RECIPES/RECIPE/NO_CHILL_EXTRA_MINUTES
# /RECIPES/RECIPE/PITCH_RATE
# /RECIPES/RECIPE/FERMENTABLES
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/NAME
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/VERSION
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/TYPE
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/AMOUNT
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/YIELD
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/COLOR
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/ADD_AFTER_BOIL
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[1]/ORIGIN
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/NAME
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/VERSION
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/TYPE
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/AMOUNT
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/YIELD
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/COLOR
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/ADD_AFTER_BOIL
# /RECIPES/RECIPE/FERMENTABLES/FERMENTABLE[2]/ORIGIN
# /RECIPES/RECIPE/HOPS
# /RECIPES/RECIPE/HOPS/HOP[1]
# /RECIPES/RECIPE/HOPS/HOP[1]/NAME
# /RECIPES/RECIPE/HOPS/HOP[1]/VERSION
# /RECIPES/RECIPE/HOPS/HOP[1]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[1]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[1]/USE
# /RECIPES/RECIPE/HOPS/HOP[1]/USER_HOP_USE
# /RECIPES/RECIPE/HOPS/HOP[1]/TIME
# /RECIPES/RECIPE/HOPS/HOP[1]/FORM
# /RECIPES/RECIPE/HOPS/HOP[2]
# /RECIPES/RECIPE/HOPS/HOP[2]/NAME
# /RECIPES/RECIPE/HOPS/HOP[2]/VERSION
# /RECIPES/RECIPE/HOPS/HOP[2]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[2]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[2]/USE
# /RECIPES/RECIPE/HOPS/HOP[2]/USER_HOP_USE
# /RECIPES/RECIPE/HOPS/HOP[2]/TIME
# /RECIPES/RECIPE/HOPS/HOP[2]/FORM
# /RECIPES/RECIPE/HOPS/HOP[3]
# /RECIPES/RECIPE/HOPS/HOP[3]/NAME
# /RECIPES/RECIPE/HOPS/HOP[3]/VERSION
# /RECIPES/RECIPE/HOPS/HOP[3]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[3]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[3]/USE
# /RECIPES/RECIPE/HOPS/HOP[3]/USER_HOP_USE
# /RECIPES/RECIPE/HOPS/HOP[3]/TIME
# /RECIPES/RECIPE/HOPS/HOP[3]/FORM
# /RECIPES/RECIPE/HOPS/HOP[4]
# /RECIPES/RECIPE/HOPS/HOP[4]/NAME
# /RECIPES/RECIPE/HOPS/HOP[4]/VERSION
# /RECIPES/RECIPE/HOPS/HOP[4]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[4]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[4]/USE
# /RECIPES/RECIPE/HOPS/HOP[4]/USER_HOP_USE
# /RECIPES/RECIPE/HOPS/HOP[4]/TIME
# /RECIPES/RECIPE/HOPS/HOP[4]/FORM
# /RECIPES/RECIPE/HOPS/HOP[5]
# /RECIPES/RECIPE/HOPS/HOP[5]/NAME
# /RECIPES/RECIPE/HOPS/HOP[5]/VERSION
# /RECIPES/RECIPE/HOPS/HOP[5]/ALPHA
# /RECIPES/RECIPE/HOPS/HOP[5]/AMOUNT
# /RECIPES/RECIPE/HOPS/HOP[5]/USE
# /RECIPES/RECIPE/HOPS/HOP[5]/USER_HOP_USE
# /RECIPES/RECIPE/HOPS/HOP[5]/TIME
# /RECIPES/RECIPE/HOPS/HOP[5]/FORM
# /RECIPES/RECIPE/MISCS
# /RECIPES/RECIPE/MISCS/MISC
# /RECIPES/RECIPE/MISCS/MISC/NAME
# /RECIPES/RECIPE/MISCS/MISC/VERSION
# /RECIPES/RECIPE/MISCS/MISC/TYPE
# /RECIPES/RECIPE/MISCS/MISC/USE
# /RECIPES/RECIPE/MISCS/MISC/TIME
# /RECIPES/RECIPE/MISCS/MISC/AMOUNT
# /RECIPES/RECIPE/MISCS/MISC/AMOUNT_IS_WEIGHT
# /RECIPES/RECIPE/MASH
# /RECIPES/RECIPE/MASH/NAME
# /RECIPES/RECIPE/MASH/VERSION
# /RECIPES/RECIPE/MASH/GRAIN_TEMP
# /RECIPES/RECIPE/MASH/MASH_STEPS
# /RECIPES/RECIPE/MASH/MASH_STEPS/MASH_STEP
# /RECIPES/RECIPE/MASH/MASH_STEPS/MASH_STEP/NAME
# /RECIPES/RECIPE/MASH/MASH_STEPS/MASH_STEP/VERSION
# /RECIPES/RECIPE/MASH/MASH_STEPS/MASH_STEP/TYPE
# /RECIPES/RECIPE/MASH/MASH_STEPS/MASH_STEP/STEP_TIME
# /RECIPES/RECIPE/MASH/MASH_STEPS/MASH_STEP/INFUSE_AMOUNT
# /RECIPES/RECIPE/MASH/MASH_STEPS/MASH_STEP/STEP_TEMP
# /RECIPES/RECIPE/YEASTS
# /RECIPES/RECIPE/YEASTS/YEAST
# /RECIPES/RECIPE/YEASTS/YEAST/NAME
# /RECIPES/RECIPE/YEASTS/YEAST/VERSION
# /RECIPES/RECIPE/YEASTS/YEAST/TYPE
# /RECIPES/RECIPE/YEASTS/YEAST/FORM
# /RECIPES/RECIPE/YEASTS/YEAST/AMOUNT
# /RECIPES/RECIPE/YEASTS/YEAST/AMOUNT_IS_WEIGHT
# /RECIPES/RECIPE/YEASTS/YEAST/PRODUCT_ID
# /RECIPES/RECIPE/YEASTS/YEAST/LABORATORY
# /RECIPES/RECIPE/YEASTS/YEAST/ATTENUATION
# /RECIPES/RECIPE/YEASTS/YEAST/FLOCCULATION
# /RECIPES/RECIPE/YEASTS/YEAST/MIN_TEMPERATURE
# /RECIPES/RECIPE/YEASTS/YEAST/MAX_TEMPERATURE
# /RECIPES/RECIPE/WATERS
# /RECIPES/RECIPE/STYLE
# /RECIPES/RECIPE/STYLE/NAME
# /RECIPES/RECIPE/STYLE/VERSION
# /RECIPES/RECIPE/STYLE/CATEGORY
# /RECIPES/RECIPE/STYLE/CATEGORY_NUMBER
# /RECIPES/RECIPE/STYLE/STYLE_LETTER
# /RECIPES/RECIPE/STYLE/STYLE_GUIDE
# /RECIPES/RECIPE/STYLE/TYPE
# /RECIPES/RECIPE/STYLE/OG_MIN
# /RECIPES/RECIPE/STYLE/OG_MAX
# /RECIPES/RECIPE/STYLE/FG_MIN
# /RECIPES/RECIPE/STYLE/FG_MAX
# /RECIPES/RECIPE/STYLE/ABV_MIN
# /RECIPES/RECIPE/STYLE/ABV_MAX
# /RECIPES/RECIPE/STYLE/IBU_MIN
# /RECIPES/RECIPE/STYLE/IBU_MAX
# /RECIPES/RECIPE/STYLE/COLOR_MIN
# /RECIPES/RECIPE/STYLE/COLOR_MAX
